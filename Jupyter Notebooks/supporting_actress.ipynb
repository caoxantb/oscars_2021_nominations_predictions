# %%
import pandas as pd
from itertools import chain

# %%
import import_ipynb
from functions import *
# Out:
# importing Jupyter notebook from functions.ipynb

# %%
AWARD_NAMES = ["bafta", "critics", "sag", "globes"]
TRAINED_PATH = '../Awards Dataset/Best Supporting Actress/Trained Data/'
APPLIED_PATH = '../Awards Dataset/Best Supporting Actress/Applied Data/'

# %%
sup_actress_oscars_dict = df_to_dict(pd.read_csv(TRAINED_PATH + "oscar.csv", encoding='utf-8-sig'), "actor")
sup_actress_awards = read_file(AWARD_NAMES, TRAINED_PATH, False, "actor")

sup_actress_union_all = union_all(sup_actress_oscars_dict, sup_actress_awards)

# %%
sup_actress_if, sup_actress_mean = calc_values(sup_actress_oscars_dict, sup_actress_awards, sup_actress_union_all)

# %%
sup_actress_2020_awards = read_file(AWARD_NAMES, APPLIED_PATH, True, "actor")

# %%
sup_actress_2020_union_all = list(set(chain.from_iterable(sup_actress_2020_awards)))

# %%
sup_actress_final, sup_actress_prob_final = calc_bayes(sup_actress_2020_awards, sup_actress_2020_union_all, sup_actress_mean)
sup_actress_final_join = list(map(lambda name: " - ".join(name), sup_actress_final))
sup_actress_final_join[-1] = "Others"

# %%
visualize_prediction(sup_actress_final_join, sup_actress_prob_final)
