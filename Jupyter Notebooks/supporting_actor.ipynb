# %%
import pandas as pd
from itertools import chain

# %%
import import_ipynb
from functions import *
# Out:
# importing Jupyter notebook from functions.ipynb

# %%
AWARD_NAMES = ["bafta", "critics", "sag", "globes"]
TRAINED_PATH = '../Awards Dataset/Best Supporting Actor/Trained Data/'
APPLIED_PATH = '../Awards Dataset/Best Supporting Actor/Applied Data/'

# %%
sup_actor_oscars_dict = df_to_dict(pd.read_csv(TRAINED_PATH + "oscar.csv", encoding='utf-8-sig'), "actor")
sup_actor_awards = read_file(AWARD_NAMES, TRAINED_PATH, False, "actor")

sup_actor_union_all = union_all(sup_actor_oscars_dict, sup_actor_awards)

# %%
sup_actor_if, sup_actor_mean = calc_values(sup_actor_oscars_dict, sup_actor_awards, sup_actor_union_all)

# %%
sup_actor_2020_awards = read_file(AWARD_NAMES, APPLIED_PATH, True, "actor")

# %%
sup_actor_2020_union_all = list(set(chain.from_iterable(sup_actor_2020_awards)))

# %%
sup_actor_final, sup_actor_prob_final = calc_bayes(sup_actor_2020_awards, sup_actor_2020_union_all, sup_actor_mean)
sup_actor_final_join = list(map(lambda name: " - ".join(name), sup_actor_final))
sup_actor_final_join[-1] = "Others"

# %%
visualize_prediction(sup_actor_final_join, sup_actor_prob_final)
