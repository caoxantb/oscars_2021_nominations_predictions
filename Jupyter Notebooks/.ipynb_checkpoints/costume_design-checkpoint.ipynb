# %%
import pandas as pd
from itertools import chain

# %%
import import_ipynb
from functions import *
# Out:
# importing Jupyter notebook from functions.ipynb

# %%
AWARD_NAMES = ["bafta", "critics"]
TRAINED_PATH = '../Awards Dataset/Best Costume Design/Trained Data/'
APPLIED_PATH = '../Awards Dataset/Best Costume Design/Applied Data/'

# %%
cdes_oscars_dict = df_to_dict(pd.read_csv(TRAINED_PATH + "oscar.csv", encoding='utf-8-sig'))
cdes_awards = read_file(AWARD_NAMES, TRAINED_PATH)

# %%
cdes_union_all = union_all(cdes_oscars_dict, cdes_awards)

# %%
cdes_if, cdes_mean = calc_values(cdes_oscars_dict, cdes_awards, cdes_union_all)

# %%
cdes_2020_awards = read_file(AWARD_NAMES, APPLIED_PATH, True)

# %%
cdes_2020_union_all = list(set(chain.from_iterable(cdes_2020_awards)))

# %%
cdes_final, cdes_prob_final = calc_bayes(cdes_2020_awards, cdes_2020_union_all, cdes_mean, False)

# %%
visualize_prediction(cdes_final, cdes_prob_final)
