# %%
import pandas as pd
from itertools import chain

# %%
import import_ipynb
from functions import *
# Out:
# importing Jupyter notebook from functions.ipynb

# %%
AWARD_NAMES = ["bafta", "critics", "pga", "sag", "globes"]
TRAINED_PATH = '../Awards Dataset/Best Picture/Trained Data/'
APPLIED_PATH = '../Awards Dataset/Best Picture/Applied Data/'

# %%
picture_oscars_dict = df_to_dict(pd.read_csv(TRAINED_PATH + "oscar.csv", encoding='utf-8-sig'))
picture_awards = read_file(AWARD_NAMES, TRAINED_PATH)

# %%
picture_union_all = union_all(picture_oscars_dict, picture_awards)

# %%
picture_if, picture_mean = calc_values(picture_oscars_dict, picture_awards, picture_union_all)
# Out:
# [[0.92, 0.525, 0.05107142857142857],
#  [0.8027272727272727, 0.9205555555555556, 0.30714285714285716],
#  [0.7836363636363637, 0.8983333333333333, 0.32821428571428574],
#  [0.76, 0.4319444444444444, 0.1717857142857143],
#  [0.6536363636363636, 0.7530555555555556, 0.5417857142857143]]

# %%
picture_2020_awards = read_file(AWARD_NAMES, APPLIED_PATH, True)

# %%
picture_2020_union_all = list(set(chain.from_iterable(picture_2020_awards)))

# %%
picture_final, picture_prob_final = calc_bayes(picture_2020_awards, picture_2020_union_all, picture_mean, 10)

# %%
visualize_prediction(picture_final, picture_prob_final)
