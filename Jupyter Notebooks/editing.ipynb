# %%
import pandas as pd
from itertools import chain

# %%
import import_ipynb
from functions import *
# Out:
# importing Jupyter notebook from functions.ipynb

# %%
AWARD_NAMES = ["bafta", "critics", "ace"]
TRAINED_PATH = '../Awards Dataset/Best Editing/Trained Data/'
APPLIED_PATH = '../Awards Dataset/Best Editing/Applied Data/'

# %%
edit_oscars_dict = df_to_dict(pd.read_csv(TRAINED_PATH + "oscar.csv", encoding='utf-8-sig'))
edit_awards = read_file(AWARD_NAMES, TRAINED_PATH)

# %%
edit_union_all = union_all(edit_oscars_dict, edit_awards)

# %%
edit_if, edit_mean = calc_values(edit_oscars_dict, edit_awards, edit_union_all)

# %%
edit_2020_awards = read_file(AWARD_NAMES, APPLIED_PATH, True)

# %%
edit_2020_union_all = list(set(chain.from_iterable(edit_2020_awards)))

# %%
edit_final, edit_prob_final = calc_bayes(edit_2020_awards, edit_2020_union_all, edit_mean)

# %%
visualize_prediction(edit_final, edit_prob_final)
