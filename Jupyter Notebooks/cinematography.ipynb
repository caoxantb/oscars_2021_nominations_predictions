# %%
import pandas as pd
from itertools import chain

# %%
import import_ipynb
from functions import *
# Out:
# importing Jupyter notebook from functions.ipynb

# %%
AWARD_NAMES = ["bafta", "critics", "asc"]
TRAINED_PATH = '../Awards Dataset/Best Cinematography/Trained Data/'
APPLIED_PATH = '../Awards Dataset/Best Cinematography/Applied Data/'

# %%
cine_oscars_dict = df_to_dict(pd.read_csv(TRAINED_PATH + "oscar.csv", encoding='utf-8-sig'))
cine_awards = read_file(AWARD_NAMES, TRAINED_PATH)

# %%
cine_union_all = union_all(cine_oscars_dict, cine_awards)

# %%
cine_if, cine_mean = calc_values(cine_oscars_dict, cine_awards, cine_union_all)

# %%
cine_2020_awards = read_file(AWARD_NAMES, APPLIED_PATH, True)

# %%
cine_2020_union_all = list(set(chain.from_iterable(cine_2020_awards)))

# %%
cine_final, cine_prob_final = calc_bayes(cine_2020_awards, cine_2020_union_all, cine_mean)

# %%
visualize_prediction(cine_final, cine_prob_final)
