# %%
import pandas as pd
from itertools import chain

# %%
import import_ipynb
from functions import *
# Out:
# importing Jupyter notebook from functions.ipynb

# %%
AWARD_NAMES = ["bafta", "critics", "wga", "globes"]
TRAINED_PATH = '../Awards Dataset/Best Original Screenplay/Trained Data/'
APPLIED_PATH = '../Awards Dataset/Best Original Screenplay/Applied Data/'

# %%
ori_script_oscars_dict = df_to_dict(pd.read_csv(TRAINED_PATH + "oscar.csv", encoding='utf-8-sig'))
ori_script_awards = read_file(AWARD_NAMES, TRAINED_PATH)

# %%
ori_script_union_all = union_all(ori_script_oscars_dict, ori_script_awards)

# %%
ori_script_if, ori_script_mean = calc_values(ori_script_oscars_dict, ori_script_awards, ori_script_union_all)

# %%
ori_script_2020_awards = read_file(AWARD_NAMES, APPLIED_PATH, True)

# %%
ori_script_2020_union_all = list(set(chain.from_iterable(ori_script_2020_awards)))

# %%
ori_script_final, ori_script_prob_final = calc_bayes(ori_script_2020_awards, ori_script_2020_union_all, ori_script_mean)

# %%
visualize_prediction(ori_script_final, ori_script_prob_final)
